# %% [markdown]
# # Step 1: Preprocessing

# %%
#Import Libraries and Dependencies 
import pandas as pd
import datetime
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder,StandardScaler

# %%
# Import CSV and Convert to DataFrame 
df1 = pd.read_csv(Path('/Users/kristenmaskery/Desktop/CrimeStoppers/Resources/crime_rate.csv'))
df1=pd.DataFrame(df1)
df1.tail()
# Out:
#                    X             Y  Index_ event_unique_id  \
# 206430 -8.855354e+06  5.426936e+06  206214  GO-20191554251
# 206431 -8.847784e+06  5.416596e+06  206215  GO-20191535011
# 206432 -8.857803e+06  5.428142e+06  206216  GO-20191534561
# 206433 -8.850567e+06  5.415343e+06  206217  GO-20191536931
# 206434 -8.849009e+06  5.421924e+06  206218  GO-20191539696
#
#                 occurrencedate            reporteddate premisetype  ucr_code  \
# 206430  2019/08/13 04:00:00+00  2019/08/16 04:00:00+00     Outside      2135
# 206431  2019/08/13 04:00:00+00  2019/08/13 04:00:00+00  Commercial      2135
# 206432  2019/08/13 04:00:00+00  2019/08/13 04:00:00+00     Outside      2135
# 206433  2019/08/13 04:00:00+00  2019/08/13 04:00:00+00     Outside      2135
# 206434  2019/08/13 04:00:00+00  2019/08/14 04:00:00+00       House      2135
#
#         ucr_ext                 offence  ...  occurrencedayofyear  \
# 206430      210  Theft Of Motor Vehicle  ...                225.0
# 206431      210  Theft Of Motor Vehicle  ...                225.0
# 206432      210  Theft Of Motor Vehicle  ...                225.0
# 206433      210  Theft Of Motor Vehicle  ...                225.0
# 206434      210  Theft Of Motor Vehicle  ...                225.0
#
#        occurrencedayofweek  occurrencehour         MCI Division  Hood_ID  \
# 206430          Tuesday                 17  Auto Theft      D31       21
# 206431          Tuesday                 14  Auto Theft      D12      111
# 206432          Tuesday                 13  Auto Theft      D31       21
# 206433          Tuesday                 11  Auto Theft      D12      111
# 206434          Tuesday                 22  Auto Theft      D12       29
#
#                   Neighbourhood        Lat    Long  ObjectId
# 206430       Humber Summit (21)  43.750652 -79.549    206431
# 206431  Rockcliffe-Smythe (111)  43.683521 -79.481    206432
# 206432       Humber Summit (21)  43.758480 -79.571    206433
# 206433  Rockcliffe-Smythe (111)  43.675377 -79.506    206434
# 206434          Maple Leaf (29)  43.718124 -79.492    206435
#
# [5 rows x 29 columns]

# %%
#Drop Unnesccesary Columns in Crime Df 
df1.drop('X', axis=1, inplace=True)
df1.drop('Y', axis=1, inplace=True)
df1.drop('reporteddate', axis=1, inplace=True)
df1.drop('premisetype', axis=1, inplace=True)
df1.drop('ucr_code', axis=1, inplace=True)
df1.drop('ucr_ext', axis=1, inplace=True)
df1.drop('Index_', axis=1, inplace=True)
df1.drop('event_unique_id', axis=1, inplace=True)
df1.drop('occurrencedayofyear', axis=1, inplace=True)
df1.drop('reportedmonth', axis=1, inplace=True)
df1.drop('reportedday', axis=1, inplace=True)
df1.drop('reporteddayofyear', axis=1, inplace=True)
df1.drop('reporteddayofweek', axis=1, inplace=True)
df1.drop('reportedhour', axis=1, inplace=True)
df1.drop('occurrenceyear', axis=1, inplace=True)
df1.drop('Division', axis=1, inplace=True)
df1.drop('Hood_ID', axis=1, inplace=True)
df1
# Out:
#                 occurrencedate                 offence  reportedyear  \
# 0       2014/01/07 05:00:00+00     Assault With Weapon          2014
# 1       2014/01/07 05:00:00+00     Assault With Weapon          2014
# 2       2014/01/07 05:00:00+00     Assault With Weapon          2014
# 3       2014/01/07 05:00:00+00     Assault With Weapon          2014
# 4       2014/01/07 05:00:00+00                     B&E          2014
# ...                        ...                     ...           ...
# 206430  2019/08/13 04:00:00+00  Theft Of Motor Vehicle          2019
# 206431  2019/08/13 04:00:00+00  Theft Of Motor Vehicle          2019
# 206432  2019/08/13 04:00:00+00  Theft Of Motor Vehicle          2019
# 206433  2019/08/13 04:00:00+00  Theft Of Motor Vehicle          2019
# 206434  2019/08/13 04:00:00+00  Theft Of Motor Vehicle          2019
#
#        occurrencemonth  occurrenceday occurrencedayofweek  occurrencehour  \
# 0              January            7.0          Tuesday                 22
# 1              January            7.0          Tuesday                 22
# 2              January            7.0          Tuesday                 22
# 3              January            7.0          Tuesday                 22
# 4              January            7.0          Tuesday                 21
# ...                ...            ...                 ...             ...
# 206430          August           13.0          Tuesday                 17
# 206431          August           13.0          Tuesday                 14
# 206432          August           13.0          Tuesday                 13
# 206433          August           13.0          Tuesday                 11
# 206434          August           13.0          Tuesday                 22
#
#                     MCI            Neighbourhood        Lat    Long  ObjectId
# 0               Assault    Newtonbrook West (36)  43.781639 -79.416         1
# 1               Assault    Newtonbrook West (36)  43.781639 -79.416         2
# 2               Assault    Newtonbrook West (36)  43.781639 -79.416         3
# 3               Assault    Newtonbrook West (36)  43.781639 -79.416         4
# 4       Break and Enter          University (79)  43.665390 -79.410         5
# ...                 ...                      ...        ...     ...       ...
# 206430       Auto Theft       Humber Summit (21)  43.750652 -79.549    206431
# 206431       Auto Theft  Rockcliffe-Smythe (111)  43.683521 -79.481    206432
# 206432       Auto Theft       Humber Summit (21)  43.758480 -79.571    206433
# 206433       Auto Theft  Rockcliffe-Smythe (111)  43.675377 -79.506    206434
# 206434       Auto Theft          Maple Leaf (29)  43.718124 -79.492    206435
#
# [206435 rows x 12 columns]

# %%
#Strip Date Column 
df1['occurrencedate'] = df1['occurrencedate'].map(lambda x: str(x)[:+10])
df1
# Out:
#        occurrencedate                 offence  reportedyear occurrencemonth  \
# 0          2014/01/07     Assault With Weapon          2014         January
# 1          2014/01/07     Assault With Weapon          2014         January
# 2          2014/01/07     Assault With Weapon          2014         January
# 3          2014/01/07     Assault With Weapon          2014         January
# 4          2014/01/07                     B&E          2014         January
# ...               ...                     ...           ...             ...
# 206430     2019/08/13  Theft Of Motor Vehicle          2019          August
# 206431     2019/08/13  Theft Of Motor Vehicle          2019          August
# 206432     2019/08/13  Theft Of Motor Vehicle          2019          August
# 206433     2019/08/13  Theft Of Motor Vehicle          2019          August
# 206434     2019/08/13  Theft Of Motor Vehicle          2019          August
#
#         occurrenceday occurrencedayofweek  occurrencehour              MCI  \
# 0                 7.0          Tuesday                 22          Assault
# 1                 7.0          Tuesday                 22          Assault
# 2                 7.0          Tuesday                 22          Assault
# 3                 7.0          Tuesday                 22          Assault
# 4                 7.0          Tuesday                 21  Break and Enter
# ...               ...                 ...             ...              ...
# 206430           13.0          Tuesday                 17       Auto Theft
# 206431           13.0          Tuesday                 14       Auto Theft
# 206432           13.0          Tuesday                 13       Auto Theft
# 206433           13.0          Tuesday                 11       Auto Theft
# 206434           13.0          Tuesday                 22       Auto Theft
#
#                   Neighbourhood        Lat    Long  ObjectId
# 0         Newtonbrook West (36)  43.781639 -79.416         1
# 1         Newtonbrook West (36)  43.781639 -79.416         2
# 2         Newtonbrook West (36)  43.781639 -79.416         3
# 3         Newtonbrook West (36)  43.781639 -79.416         4
# 4               University (79)  43.665390 -79.410         5
# ...                         ...        ...     ...       ...
# 206430       Humber Summit (21)  43.750652 -79.549    206431
# 206431  Rockcliffe-Smythe (111)  43.683521 -79.481    206432
# 206432       Humber Summit (21)  43.758480 -79.571    206433
# 206433  Rockcliffe-Smythe (111)  43.675377 -79.506    206434
# 206434          Maple Leaf (29)  43.718124 -79.492    206435
#
# [206435 rows x 12 columns]

# %%
#Rename Occurence Column to merge with df2
df1 = df1.rename({'occurrencedate': 'Date'}, axis=1)
df1 = df1.rename({'occurrencehour':'hour_num'}, axis=1)          
df1.head()
# Out:
#          Date              offence  reportedyear occurrencemonth  \
# 0  2014/01/07  Assault With Weapon          2014         January
# 1  2014/01/07  Assault With Weapon          2014         January
# 2  2014/01/07  Assault With Weapon          2014         January
# 3  2014/01/07  Assault With Weapon          2014         January
# 4  2014/01/07                  B&E          2014         January
#
#    occurrenceday occurrencedayofweek  hour_num              MCI  \
# 0            7.0          Tuesday           22          Assault
# 1            7.0          Tuesday           22          Assault
# 2            7.0          Tuesday           22          Assault
# 3            7.0          Tuesday           22          Assault
# 4            7.0          Tuesday           21  Break and Enter
#
#            Neighbourhood        Lat    Long  ObjectId
# 0  Newtonbrook West (36)  43.781639 -79.416         1
# 1  Newtonbrook West (36)  43.781639 -79.416         2
# 2  Newtonbrook West (36)  43.781639 -79.416         3
# 3  Newtonbrook West (36)  43.781639 -79.416         4
# 4        University (79)  43.665390 -79.410         5

# %%
# convert the 'Date' column to datetime format
df1['Date'] = pd.to_datetime(df1['Date'], infer_datetime_format=True)
df1
#set start and end date for years we want to keep
start_date = '01-08-2014'
end_date = '11-14-2018'
#Add them to the df2
mask = (df1['Date'] > start_date) & (df1['Date'] <= end_date)
df1 = df1.loc[mask]
df1
#convert occurenceday column to integer
df1['occurrenceday'] = df1['occurrenceday'].astype(int)
df1
# Out:
#              Date                 offence  reportedyear occurrencemonth  \
# 5      2014-01-09                     B&E          2014         January
# 6      2014-01-16                 Assault          2014         January
# 7      2014-01-16                 Assault          2014         January
# 8      2014-01-16                     B&E          2014         January
# 9      2014-01-16      Robbery - Business          2014         January
# ...           ...                     ...           ...             ...
# 205885 2018-11-14  Theft Of Motor Vehicle          2018        November
# 205886 2018-11-14  Theft Of Motor Vehicle          2018        November
# 205887 2018-11-14  Theft Of Motor Vehicle          2018        November
# 205888 2018-11-14  Theft Of Motor Vehicle          2018        November
# 205889 2018-11-14  Theft Of Motor Vehicle          2018        November
#
#         occurrenceday occurrencedayofweek  hour_num              MCI  \
# 5                   9          Thursday          11  Break and Enter
# 6                  16          Thursday           0          Assault
# 7                  16          Thursday           2          Assault
# 8                  16          Thursday          17  Break and Enter
# 9                  16          Thursday          19          Robbery
# ...               ...                 ...       ...              ...
# 205885             14          Wednesday         11       Auto Theft
# 205886             14          Wednesday         22       Auto Theft
# 205887             14          Wednesday         19       Auto Theft
# 205888             14          Wednesday         20       Auto Theft
# 205889             14          Wednesday         22       Auto Theft
#
#                           Neighbourhood        Lat    Long  ObjectId
# 5       Islington-City Centre West (14)  43.646061 -79.531         6
# 6                    Junction Area (90)  43.663498 -79.462         7
# 7              Bay Street Corridor (76)  43.657040 -79.381         8
# 8             Scarborough Village (139)  43.744343 -79.214         9
# 9                    Humber Summit (21)  43.748562 -79.559        10
# ...                                 ...        ...     ...       ...
# 205885                    Wychwood (94)  43.682190 -79.419    205886
# 205886          Yorkdale-Glen Park (31)  43.717758 -79.468    205887
# 205887                Clanton Park (33)  43.735584 -79.443    205888
# 205888           Woodbine Corridor (64)  43.667030 -79.314    205889
# 205889     York University Heights (27)  43.759750 -79.500    205890
#
# [162096 rows x 12 columns]

# %%
#read in temperature data 
df2 = pd.read_csv(Path('/Users/kristenmaskery/Desktop/CrimeStoppers/Resources/Toronto_temp_clean.csv'))
df2=pd.DataFrame(df2)
df2
# Out:
#            Date_  Year_  Month_  Day_  Mean_temp  Total_Precip  Season Rain  \
# 0     2018-01-31  2,018       1    31       -7.0           1.0  Winter   No
# 1     2018-01-30  2,018       1    30      -11.0           0.0  Winter   No
# 2     2018-01-29  2,018       1    29       -4.0           5.0  Winter   No
# 3     2018-01-28  2,018       1    28        1.0           0.0  Winter   No
# 4     2018-01-27  2,018       1    27        5.0           2.0  Winter  Yes
# ...          ...    ...     ...   ...        ...           ...     ...  ...
# 2884  1941-12-01   1941      12     1       -1.5          41.1  Winter  Yes
# 2885  1940-12-01   1940      12     1       -3.6          82.6  Winter  Yes
# 2886  1939-12-01   1939      12     1        NaN           NaN  Winter   No
# 2887  1938-12-01   1938      12     1       -2.5          27.4  Winter  Yes
# 2888  1937-12-01   1937      12     1       -4.4          41.4  Winter  Yes
#
#      Snow
# 0     Yes
# 1      No
# 2     Yes
# 3      No
# 4      No
# ...   ...
# 2884  Yes
# 2885  Yes
# 2886   No
# 2887  Yes
# 2888  Yes
#
# [2889 rows x 9 columns]

# %%
#Rename Date_ Column to merge with df1
df2 = df2.rename({'Date_': 'Date'}, axis=1)
df2.head()
# Out:
#          Date  Year_  Month_  Day_  Mean_temp  Total_Precip  Season Rain Snow
# 0  2018-01-31  2,018       1    31       -7.0           1.0  Winter   No  Yes
# 1  2018-01-30  2,018       1    30      -11.0           0.0  Winter   No   No
# 2  2018-01-29  2,018       1    29       -4.0           5.0  Winter   No  Yes
# 3  2018-01-28  2,018       1    28        1.0           0.0  Winter   No   No
# 4  2018-01-27  2,018       1    27        5.0           2.0  Winter  Yes   No

# %%
#Convert Date column to date time 
df2['Date'] = pd.to_datetime(df2['Date']) 
df2.head()
#set start and end date for years we want to keep
start_date = '01-08-2014'
end_date = '01-01-2019'
#Add them to the df2
mask = (df2['Date'] > start_date) & (df2['Date'] <= end_date)
df2 = df2.loc[mask]
#Sort Values from 2014 to 2018
df2.sort_values(by=['Date'], inplace=True, ascending=True)
df2
# Out:
#            Date  Year_  Month_  Day_  Mean_temp  Total_Precip  Season Rain  \
# 146  2014-01-09  2,014       1     9      -11.0           0.0  Winter   No
# 145  2014-01-10  2,014       1    10       -3.0           3.0  Winter  Yes
# 144  2014-01-11  2,014       1    11        4.0           8.0  Winter  Yes
# 143  2014-01-12  2,014       1    12        1.0           0.0  Winter   No
# 142  2014-01-13  2,014       1    13        4.0           1.0  Winter  Yes
# ...         ...    ...     ...   ...        ...           ...     ...  ...
# 2422 2018-11-10  2,018      11    10        0.0           0.0    Fall   No
# 2421 2018-11-11  2,018      11    11        1.0           0.0    Fall   No
# 2420 2018-11-12  2,018      11    12        4.0           1.0    Fall  Yes
# 2419 2018-11-13  2,018      11    13       -1.0           1.0    Fall  Yes
# 2418 2018-11-14  2,018      11    14       -2.0           0.0    Fall   No
#
#      Snow
# 146    No
# 145   Yes
# 144    No
# 143    No
# 142    No
# ...   ...
# 2422   No
# 2421   No
# 2420   No
# 2419   No
# 2418   No
#
# [1771 rows x 9 columns]

# %%
df1.to_csv('cleaned_crime_rate.csv', index = False)
df2.to_csv('cleaned_temp_rate.csv', index = False)

# %%
#Merge df1 & df2 on date column
merged_df = pd.merge(left=df1, right=df2, how='left', left_on='Date', right_on='Date')
merged_df
# Out:
#              Date                 offence  reportedyear occurrencemonth  \
# 0      2014-01-09                     B&E          2014         January
# 1      2014-01-16                 Assault          2014         January
# 2      2014-01-16                 Assault          2014         January
# 3      2014-01-16                     B&E          2014         January
# 4      2014-01-16      Robbery - Business          2014         January
# ...           ...                     ...           ...             ...
# 162091 2018-11-14  Theft Of Motor Vehicle          2018        November
# 162092 2018-11-14  Theft Of Motor Vehicle          2018        November
# 162093 2018-11-14  Theft Of Motor Vehicle          2018        November
# 162094 2018-11-14  Theft Of Motor Vehicle          2018        November
# 162095 2018-11-14  Theft Of Motor Vehicle          2018        November
#
#         occurrenceday occurrencedayofweek  hour_num              MCI  \
# 0                   9          Thursday          11  Break and Enter
# 1                  16          Thursday           0          Assault
# 2                  16          Thursday           2          Assault
# 3                  16          Thursday          17  Break and Enter
# 4                  16          Thursday          19          Robbery
# ...               ...                 ...       ...              ...
# 162091             14          Wednesday         11       Auto Theft
# 162092             14          Wednesday         22       Auto Theft
# 162093             14          Wednesday         19       Auto Theft
# 162094             14          Wednesday         20       Auto Theft
# 162095             14          Wednesday         22       Auto Theft
#
#                           Neighbourhood        Lat    Long  ObjectId  Year_  \
# 0       Islington-City Centre West (14)  43.646061 -79.531         6  2,014
# 1                    Junction Area (90)  43.663498 -79.462         7  2,014
# 2              Bay Street Corridor (76)  43.657040 -79.381         8  2,014
# 3             Scarborough Village (139)  43.744343 -79.214         9  2,014
# 4                    Humber Summit (21)  43.748562 -79.559        10  2,014
# ...                                 ...        ...     ...       ...    ...
# 162091                    Wychwood (94)  43.682190 -79.419    205886  2,018
# 162092          Yorkdale-Glen Park (31)  43.717758 -79.468    205887  2,018
# 162093                Clanton Park (33)  43.735584 -79.443    205888  2,018
# 162094           Woodbine Corridor (64)  43.667030 -79.314    205889  2,018
# 162095     York University Heights (27)  43.759750 -79.500    205890  2,018
#
#         Month_  Day_  Mean_temp  Total_Precip  Season Rain Snow
# 0            1     9      -11.0           0.0  Winter   No   No
# 1            1    16       -3.0           2.0  Winter   No  Yes
# 2            1    16       -3.0           2.0  Winter   No  Yes
# 3            1    16       -3.0           2.0  Winter   No  Yes
# 4            1    16       -3.0           2.0  Winter   No  Yes
# ...        ...   ...        ...           ...     ...  ...  ...
# 162091      11    14       -2.0           0.0    Fall   No   No
# 162092      11    14       -2.0           0.0    Fall   No   No
# 162093      11    14       -2.0           0.0    Fall   No   No
# 162094      11    14       -2.0           0.0    Fall   No   No
# 162095      11    14       -2.0           0.0    Fall   No   No
#
# [162096 rows x 20 columns]

# %%
#Clean merged df 
merged_df.drop('ObjectId', axis=1, inplace=True)
merged_df.drop('offence', axis=1, inplace=True)
merged_df.drop('Year_', axis=1, inplace=True)
merged_df.drop('Day_', axis=1, inplace=True)
merged_df.drop('Month_', axis=1, inplace=True)

merged_df
# Out:
#              Date  reportedyear occurrencemonth  occurrenceday  \
# 0      2014-01-09          2014         January              9
# 1      2014-01-16          2014         January             16
# 2      2014-01-16          2014         January             16
# 3      2014-01-16          2014         January             16
# 4      2014-01-16          2014         January             16
# ...           ...           ...             ...            ...
# 162091 2018-11-14          2018        November             14
# 162092 2018-11-14          2018        November             14
# 162093 2018-11-14          2018        November             14
# 162094 2018-11-14          2018        November             14
# 162095 2018-11-14          2018        November             14
#
#        occurrencedayofweek  hour_num              MCI  \
# 0               Thursday          11  Break and Enter
# 1               Thursday           0          Assault
# 2               Thursday           2          Assault
# 3               Thursday          17  Break and Enter
# 4               Thursday          19          Robbery
# ...                    ...       ...              ...
# 162091          Wednesday         11       Auto Theft
# 162092          Wednesday         22       Auto Theft
# 162093          Wednesday         19       Auto Theft
# 162094          Wednesday         20       Auto Theft
# 162095          Wednesday         22       Auto Theft
#
#                           Neighbourhood        Lat    Long  Mean_temp  \
# 0       Islington-City Centre West (14)  43.646061 -79.531      -11.0
# 1                    Junction Area (90)  43.663498 -79.462       -3.0
# 2              Bay Street Corridor (76)  43.657040 -79.381       -3.0
# 3             Scarborough Village (139)  43.744343 -79.214       -3.0
# 4                    Humber Summit (21)  43.748562 -79.559       -3.0
# ...                                 ...        ...     ...        ...
# 162091                    Wychwood (94)  43.682190 -79.419       -2.0
# 162092          Yorkdale-Glen Park (31)  43.717758 -79.468       -2.0
# 162093                Clanton Park (33)  43.735584 -79.443       -2.0
# 162094           Woodbine Corridor (64)  43.667030 -79.314       -2.0
# 162095     York University Heights (27)  43.759750 -79.500       -2.0
#
#         Total_Precip  Season Rain Snow
# 0                0.0  Winter   No   No
# 1                2.0  Winter   No  Yes
# 2                2.0  Winter   No  Yes
# 3                2.0  Winter   No  Yes
# 4                2.0  Winter   No  Yes
# ...              ...     ...  ...  ...
# 162091           0.0    Fall   No   No
# 162092           0.0    Fall   No   No
# 162093           0.0    Fall   No   No
# 162094           0.0    Fall   No   No
# 162095           0.0    Fall   No   No
#
# [162096 rows x 15 columns]

# %%
#Create Instance of Label Encoder
label_encoder = LabelEncoder()

# %%
#Fit the Label Encoder 
label_encoder.fit(merged_df["Season"])
# Out:
# LabelEncoder()

# %%
# List the Encoded Classes
list(label_encoder.classes_)
# Encode the Seasons as an Integer
merged_df["Seasons"] = label_encoder.transform(merged_df["Season"])
merged_df.head()
#Seasons Dictionary
seasons_num = {
    "Fall": 1,
    "Spring": 2,
    "Summer": 3,
    "Winter": 4,
}
#Add Months Dictionary to DataFrame
merged_df["Seasons_Num"] = merged_df["Season"].apply(lambda x: seasons_num[x])
merged_df.head()
# Out:
#         Date  reportedyear occurrencemonth  occurrenceday occurrencedayofweek  \
# 0 2014-01-09          2014         January              9          Thursday
# 1 2014-01-16          2014         January             16          Thursday
# 2 2014-01-16          2014         January             16          Thursday
# 3 2014-01-16          2014         January             16          Thursday
# 4 2014-01-16          2014         January             16          Thursday
#
#    hour_num              MCI                    Neighbourhood        Lat  \
# 0        11  Break and Enter  Islington-City Centre West (14)  43.646061
# 1         0          Assault               Junction Area (90)  43.663498
# 2         2          Assault         Bay Street Corridor (76)  43.657040
# 3        17  Break and Enter        Scarborough Village (139)  43.744343
# 4        19          Robbery               Humber Summit (21)  43.748562
#
#      Long  Mean_temp  Total_Precip  Season Rain Snow  Seasons  Seasons_Num
# 0 -79.531      -11.0           0.0  Winter   No   No        3            4
# 1 -79.462       -3.0           2.0  Winter   No  Yes        3            4
# 2 -79.381       -3.0           2.0  Winter   No  Yes        3            4
# 3 -79.214       -3.0           2.0  Winter   No  Yes        3            4
# 4 -79.559       -3.0           2.0  Winter   No  Yes        3            4

# %%
#Drop Seasons Column 
merged_df.drop(["Season", "Seasons"], axis=1, inplace=True)
merged_df.head()
# Out:
#         Date  reportedyear occurrencemonth  occurrenceday occurrencedayofweek  \
# 0 2014-01-09          2014         January              9          Thursday
# 1 2014-01-16          2014         January             16          Thursday
# 2 2014-01-16          2014         January             16          Thursday
# 3 2014-01-16          2014         January             16          Thursday
# 4 2014-01-16          2014         January             16          Thursday
#
#    hour_num              MCI                    Neighbourhood        Lat  \
# 0        11  Break and Enter  Islington-City Centre West (14)  43.646061
# 1         0          Assault               Junction Area (90)  43.663498
# 2         2          Assault         Bay Street Corridor (76)  43.657040
# 3        17  Break and Enter        Scarborough Village (139)  43.744343
# 4        19          Robbery               Humber Summit (21)  43.748562
#
#      Long  Mean_temp  Total_Precip Rain Snow  Seasons_Num
# 0 -79.531      -11.0           0.0   No   No            4
# 1 -79.462       -3.0           2.0   No  Yes            4
# 2 -79.381       -3.0           2.0   No  Yes            4
# 3 -79.214       -3.0           2.0   No  Yes            4
# 4 -79.559       -3.0           2.0   No  Yes            4

# %%
#Create Second Instance of Label Encoder
label_encoder = LabelEncoder()
#Fit the Label Encoder 
label_encoder.fit(merged_df["MCI"])
# Out:
# LabelEncoder()

# %%
# List the Encoded Classes
list(label_encoder.classes_)
# Encode the MCI's as an Integer
merged_df["Offences_Type"] = label_encoder.transform(merged_df["MCI"])
merged_df.head()
# Out:
#         Date  reportedyear occurrencemonth  occurrenceday occurrencedayofweek  \
# 0 2014-01-09          2014         January              9          Thursday
# 1 2014-01-16          2014         January             16          Thursday
# 2 2014-01-16          2014         January             16          Thursday
# 3 2014-01-16          2014         January             16          Thursday
# 4 2014-01-16          2014         January             16          Thursday
#
#    hour_num              MCI                    Neighbourhood        Lat  \
# 0        11  Break and Enter  Islington-City Centre West (14)  43.646061
# 1         0          Assault               Junction Area (90)  43.663498
# 2         2          Assault         Bay Street Corridor (76)  43.657040
# 3        17  Break and Enter        Scarborough Village (139)  43.744343
# 4        19          Robbery               Humber Summit (21)  43.748562
#
#      Long  Mean_temp  Total_Precip Rain Snow  Seasons_Num  Offences_Type
# 0 -79.531      -11.0           0.0   No   No            4              2
# 1 -79.462       -3.0           2.0   No  Yes            4              0
# 2 -79.381       -3.0           2.0   No  Yes            4              0
# 3 -79.214       -3.0           2.0   No  Yes            4              2
# 4 -79.559       -3.0           2.0   No  Yes            4              3

# %%
#MCI Dictionary
Offences_num = {
    "Assault": 1,
    "Auto Theft": 2,
    "Break and Enter": 3,
    "Robbery": 4,
    "Theft Over":5,
}
#Add MCI Dictionary to DataFrame
merged_df["Offences_type"] = merged_df["MCI"].apply(lambda x: Offences_num[x])
merged_df.head()
# Drop MCI & Offences_Type Columns 
merged_df.drop(["MCI", "Offences_Type"], axis=1, inplace=True)
merged_df.head()
# Out:
#         Date  reportedyear occurrencemonth  occurrenceday occurrencedayofweek  \
# 0 2014-01-09          2014         January              9          Thursday
# 1 2014-01-16          2014         January             16          Thursday
# 2 2014-01-16          2014         January             16          Thursday
# 3 2014-01-16          2014         January             16          Thursday
# 4 2014-01-16          2014         January             16          Thursday
#
#    hour_num                    Neighbourhood        Lat    Long  Mean_temp  \
# 0        11  Islington-City Centre West (14)  43.646061 -79.531      -11.0
# 1         0               Junction Area (90)  43.663498 -79.462       -3.0
# 2         2         Bay Street Corridor (76)  43.657040 -79.381       -3.0
# 3        17        Scarborough Village (139)  43.744343 -79.214       -3.0
# 4        19               Humber Summit (21)  43.748562 -79.559       -3.0
#
#    Total_Precip Rain Snow  Seasons_Num  Offences_type
# 0           0.0   No   No            4              3
# 1           2.0   No  Yes            4              1
# 2           2.0   No  Yes            4              1
# 3           2.0   No  Yes            4              3
# 4           2.0   No  Yes            4              4

# %%
#Create Instance of Label Encoder
label_encoder = LabelEncoder()
#Fit the Label Encoder 
label_encoder.fit(merged_df["occurrencedayofweek"])
# List the Encoded Classes
list(label_encoder.classes_)
# Encode the weekday as an Integer
merged_df["Day_Of_Week"] = label_encoder.transform(merged_df["occurrencedayofweek"])
merged_df.head()
# Out:
#         Date  reportedyear occurrencemonth  occurrenceday occurrencedayofweek  \
# 0 2014-01-09          2014         January              9          Thursday
# 1 2014-01-16          2014         January             16          Thursday
# 2 2014-01-16          2014         January             16          Thursday
# 3 2014-01-16          2014         January             16          Thursday
# 4 2014-01-16          2014         January             16          Thursday
#
#    hour_num                    Neighbourhood        Lat    Long  Mean_temp  \
# 0        11  Islington-City Centre West (14)  43.646061 -79.531      -11.0
# 1         0               Junction Area (90)  43.663498 -79.462       -3.0
# 2         2         Bay Street Corridor (76)  43.657040 -79.381       -3.0
# 3        17        Scarborough Village (139)  43.744343 -79.214       -3.0
# 4        19               Humber Summit (21)  43.748562 -79.559       -3.0
#
#    Total_Precip Rain Snow  Seasons_Num  Offences_type  Day_Of_Week
# 0           0.0   No   No            4              3            4
# 1           2.0   No  Yes            4              1            4
# 2           2.0   No  Yes            4              1            4
# 3           2.0   No  Yes            4              3            4
# 4           2.0   No  Yes            4              4            4

# %%
#Weekday Dictionary
Week_day_num = {
    "Monday    ": 1,
    "Tuesday   ": 2,
    "Wednesday ": 3,
    "Thursday  ": 4,
    "Friday    ": 5,
    "Saturday  ": 6,
    "Sunday    ": 7,
}
#Add Months Dictionary to DataFrame
merged_df["Day_Of_Week"] = merged_df["occurrencedayofweek"].apply(lambda x: Week_day_num[x])
merged_df.head()
#Drop columns
merged_df.drop(["occurrencedayofweek"], axis=1, inplace=True)
merged_df.head()
# Out:
#         Date  reportedyear occurrencemonth  occurrenceday  hour_num  \
# 0 2014-01-09          2014         January              9        11
# 1 2014-01-16          2014         January             16         0
# 2 2014-01-16          2014         January             16         2
# 3 2014-01-16          2014         January             16        17
# 4 2014-01-16          2014         January             16        19
#
#                      Neighbourhood        Lat    Long  Mean_temp  \
# 0  Islington-City Centre West (14)  43.646061 -79.531      -11.0
# 1               Junction Area (90)  43.663498 -79.462       -3.0
# 2         Bay Street Corridor (76)  43.657040 -79.381       -3.0
# 3        Scarborough Village (139)  43.744343 -79.214       -3.0
# 4               Humber Summit (21)  43.748562 -79.559       -3.0
#
#    Total_Precip Rain Snow  Seasons_Num  Offences_type  Day_Of_Week
# 0           0.0   No   No            4              3            4
# 1           2.0   No  Yes            4              1            4
# 2           2.0   No  Yes            4              1            4
# 3           2.0   No  Yes            4              3            4
# 4           2.0   No  Yes            4              4            4

# %%
#Create Instance of Label Encoder
label_encoder = LabelEncoder()
#Fit the Label Encoder 
label_encoder.fit(merged_df["occurrencemonth"])
# List the Encoded Classes
list(label_encoder.classes_)
# Encode the weekday as an Integer
merged_df["Month"] = label_encoder.transform(merged_df["occurrencemonth"])
merged_df.head()
# Out:
#         Date  reportedyear occurrencemonth  occurrenceday  hour_num  \
# 0 2014-01-09          2014         January              9        11
# 1 2014-01-16          2014         January             16         0
# 2 2014-01-16          2014         January             16         2
# 3 2014-01-16          2014         January             16        17
# 4 2014-01-16          2014         January             16        19
#
#                      Neighbourhood        Lat    Long  Mean_temp  \
# 0  Islington-City Centre West (14)  43.646061 -79.531      -11.0
# 1               Junction Area (90)  43.663498 -79.462       -3.0
# 2         Bay Street Corridor (76)  43.657040 -79.381       -3.0
# 3        Scarborough Village (139)  43.744343 -79.214       -3.0
# 4               Humber Summit (21)  43.748562 -79.559       -3.0
#
#    Total_Precip Rain Snow  Seasons_Num  Offences_type  Day_Of_Week  Month
# 0           0.0   No   No            4              3            4      4
# 1           2.0   No  Yes            4              1            4      4
# 2           2.0   No  Yes            4              1            4      4
# 3           2.0   No  Yes            4              3            4      4
# 4           2.0   No  Yes            4              4            4      4

# %%
#Month Dictionary
months_num = {
    "January": 1,
    "February": 2,
    "March": 3,
    "April": 4,
    "May": 5,
    "June": 6,
    "July": 7,
    "August": 8,
    "September": 9,
    "October": 10,
    "November": 11,
    "December": 12,
}
#Add Months Dictionary to DataFrame
merged_df["Month"] = merged_df["occurrencemonth"].apply(lambda x: months_num[x])
merged_df.head()
#Drop columns
merged_df.drop(["occurrencemonth"], axis=1, inplace=True)
merged_df.head()
# Out:
#         Date  reportedyear  occurrenceday  hour_num  \
# 0 2014-01-09          2014              9        11
# 1 2014-01-16          2014             16         0
# 2 2014-01-16          2014             16         2
# 3 2014-01-16          2014             16        17
# 4 2014-01-16          2014             16        19
#
#                      Neighbourhood        Lat    Long  Mean_temp  \
# 0  Islington-City Centre West (14)  43.646061 -79.531      -11.0
# 1               Junction Area (90)  43.663498 -79.462       -3.0
# 2         Bay Street Corridor (76)  43.657040 -79.381       -3.0
# 3        Scarborough Village (139)  43.744343 -79.214       -3.0
# 4               Humber Summit (21)  43.748562 -79.559       -3.0
#
#    Total_Precip Rain Snow  Seasons_Num  Offences_type  Day_Of_Week  Month
# 0           0.0   No   No            4              3            4      1
# 1           2.0   No  Yes            4              1            4      1
# 2           2.0   No  Yes            4              1            4      1
# 3           2.0   No  Yes            4              3            4      1
# 4           2.0   No  Yes            4              4            4      1

# %%
#Dummy Encoding the Rain & Snow Columns
temp_binary_encoded_df = pd.get_dummies(merged_df, columns=["Rain", "Snow"])
temp_binary_encoded_df.head()
# Out:
#         Date  reportedyear  occurrenceday  hour_num  \
# 0 2014-01-09          2014              9        11
# 1 2014-01-16          2014             16         0
# 2 2014-01-16          2014             16         2
# 3 2014-01-16          2014             16        17
# 4 2014-01-16          2014             16        19
#
#                      Neighbourhood        Lat    Long  Mean_temp  \
# 0  Islington-City Centre West (14)  43.646061 -79.531      -11.0
# 1               Junction Area (90)  43.663498 -79.462       -3.0
# 2         Bay Street Corridor (76)  43.657040 -79.381       -3.0
# 3        Scarborough Village (139)  43.744343 -79.214       -3.0
# 4               Humber Summit (21)  43.748562 -79.559       -3.0
#
#    Total_Precip  Seasons_Num  Offences_type  Day_Of_Week  Month  Rain_No  \
# 0           0.0            4              3            4      1        1
# 1           2.0            4              1            4      1        1
# 2           2.0            4              1            4      1        1
# 3           2.0            4              3            4      1        1
# 4           2.0            4              4            4      1        1
#
#    Rain_Yes  Snow_No  Snow_Yes
# 0         0        1         0
# 1         0        0         1
# 2         0        0         1
# 3         0        0         1
# 4         0        0         1

# %%
#Create a DataFrame of the Aggregate Crime Rate Monthly
crime_month = pd.DataFrame(temp_binary_encoded_df.Month.value_counts().reset_index().values, columns=["Month", "AggregateCrime"])
crime_month_index = crime_month.sort_index(axis = 0, ascending=True)
crime_month_index
# Out:
#     Month  AggregateCrime
# 0      10           14959
# 1       7           14697
# 2       5           14577
# 3       8           14543
# 4       6           14466
# 5       9           14361
# 6       4           13418
# 7       3           13078
# 8      11           12997
# 9       1           12475
# 10      2           11815
# 11     12           10710

# %%
plt.scatter(crime_month_index.Month, crime_month_index.AggregateCrime)
plt.xlabel('Month') 
plt.ylabel('Crime Rate')
plt.show()

# %%
#Create new df with day of the week crime rate 
Week_rate = pd.DataFrame(temp_binary_encoded_df.Day_Of_Week.value_counts().reset_index().values, columns=["Day_Of_Week", "AggregateCrime"])
Week_rate_index = Week_rate.sort_index(axis = 0, ascending=True)
Week_rate_index
# Out:
#    Day_Of_Week  AggregateCrime
# 0            5           24648
# 1            6           24370
# 2            7           23533
# 3            4           22759
# 4            3           22433
# 5            1           22364
# 6            2           21989

# %%
plt.scatter(Week_rate_index.Day_Of_Week, Week_rate_index.AggregateCrime)
plt.xlabel('Day of Week') 
plt.ylabel('Crime Rate')
plt.show()

# %%
#Create new df with hour
hour_rate = pd.DataFrame(temp_binary_encoded_df.hour_num.value_counts().reset_index().values, columns=["Hour", "AggregateCrime"])
hour_crime_rate_index = hour_rate.sort_index(axis = 0, ascending=True)
hour_crime_rate_index.head()
# Out:
#    Hour  AggregateCrime
# 0     0           10403
# 1    12            9092
# 2    21            8788
# 3    18            8741
# 4    20            8651

# %%
plt.scatter(hour_crime_rate_index.Hour, hour_crime_rate_index.AggregateCrime)
plt.xlabel('Hour(24hr)') 
plt.ylabel('Crime Rate')
plt.show()

# %%
#Create new df with Temp
Temp_rate = pd.DataFrame(temp_binary_encoded_df.Mean_temp.value_counts().reset_index().values, columns=["Mean_temp", "AggregateCrime"])
temp_crime_rate_index = Temp_rate.sort_index(axis = 0, ascending=True)
temp_crime_rate_index.head()
# Out:
#    Mean_temp  AggregateCrime
# 0       22.0          7197.0
# 1       17.0          6234.0
# 2       19.0          6151.0
# 3       20.0          6126.0
# 4       21.0          5994.0

# %%
plt.scatter(temp_crime_rate_index.Mean_temp, temp_crime_rate_index.AggregateCrime)
plt.xlabel('Mean_temp') 
plt.ylabel('Crime Rate')
plt.show()

# %%
pd.merge(crime_month_index, Week_rate_index, left_index=True, right_index=True)
# Out:
#    Month  AggregateCrime_x  Day_Of_Week  AggregateCrime_y
# 0     10             14959            5             24648
# 1      7             14697            6             24370
# 2      5             14577            7             23533
# 3      8             14543            4             22759
# 4      6             14466            3             22433
# 5      9             14361            1             22364
# 6      4             13418            2             21989
