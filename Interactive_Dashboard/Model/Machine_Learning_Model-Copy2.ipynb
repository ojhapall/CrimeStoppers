# %% [markdown]
# # Step 1: Preprocessing

# %%
#Import Libraries and Dependencies 
import pandas as pd
import datetime
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder,StandardScaler

# %%
# Import CSV and Convert to DataFrame 
df1 = pd.read_csv(Path('Resources/crime_rate.csv'))
df1=pd.DataFrame(df1)
df1.tail()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-42f5987daa92> in <module>
#       1 # Import CSV and Convert to DataFrame
# ----> 2 df1 = pd.read_csv(Path('Resources/crime_rate.csv'))
#       3 df1=pd.DataFrame(df1)
#       4 df1.tail()
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources/crime_rate.csv'

# %%
#Drop Unnesccesary Columns in Crime Df 
df1.drop('X', axis=1, inplace=True)
df1.drop('Y', axis=1, inplace=True)
df1.drop('reporteddate', axis=1, inplace=True)
df1.drop('premisetype', axis=1, inplace=True)
df1.drop('ucr_code', axis=1, inplace=True)
df1.drop('ucr_ext', axis=1, inplace=True)
df1.drop('Index_', axis=1, inplace=True)
df1.drop('event_unique_id', axis=1, inplace=True)
df1.drop('occurrencedayofyear', axis=1, inplace=True)
df1.drop('reportedmonth', axis=1, inplace=True)
df1.drop('reportedday', axis=1, inplace=True)
df1.drop('reporteddayofyear', axis=1, inplace=True)
df1.drop('reporteddayofweek', axis=1, inplace=True)
df1.drop('reportedhour', axis=1, inplace=True)
df1.drop('occurrenceyear', axis=1, inplace=True)
df1.drop('Division', axis=1, inplace=True)
df1.drop('Hood_ID', axis=1, inplace=True)
df1.drop('Neighbourhood', axis=1, inplace=True)
df1.drop('Lat', axis=1, inplace=True)
df1.drop('Long', axis=1, inplace=True)
df1.drop('ObjectId', axis=1, inplace=True)
df1.drop('offence', axis=1, inplace=True)
df1
# Out:
#                 occurrencedate  reportedyear occurrencemonth  occurrenceday  \
# 0       2014/01/07 05:00:00+00          2014         January            7.0
# 1       2014/01/07 05:00:00+00          2014         January            7.0
# 2       2014/01/07 05:00:00+00          2014         January            7.0
# 3       2014/01/07 05:00:00+00          2014         January            7.0
# 4       2014/01/07 05:00:00+00          2014         January            7.0
# ...                        ...           ...             ...            ...
# 206430  2019/08/13 04:00:00+00          2019          August           13.0
# 206431  2019/08/13 04:00:00+00          2019          August           13.0
# 206432  2019/08/13 04:00:00+00          2019          August           13.0
# 206433  2019/08/13 04:00:00+00          2019          August           13.0
# 206434  2019/08/13 04:00:00+00          2019          August           13.0
#
#        occurrencedayofweek  occurrencehour              MCI
# 0               Tuesday                 22          Assault
# 1               Tuesday                 22          Assault
# 2               Tuesday                 22          Assault
# 3               Tuesday                 22          Assault
# 4               Tuesday                 21  Break and Enter
# ...                    ...             ...              ...
# 206430          Tuesday                 17       Auto Theft
# 206431          Tuesday                 14       Auto Theft
# 206432          Tuesday                 13       Auto Theft
# 206433          Tuesday                 11       Auto Theft
# 206434          Tuesday                 22       Auto Theft
#
# [206435 rows x 7 columns]

# %%
#Strip Date Column 
df1['occurrencedate'] = df1['occurrencedate'].map(lambda x: str(x)[:+10])
df1
# Out:
#        occurrencedate  reportedyear occurrencemonth  occurrenceday  \
# 0          2014/01/07          2014         January            7.0
# 1          2014/01/07          2014         January            7.0
# 2          2014/01/07          2014         January            7.0
# 3          2014/01/07          2014         January            7.0
# 4          2014/01/07          2014         January            7.0
# ...               ...           ...             ...            ...
# 206430     2019/08/13          2019          August           13.0
# 206431     2019/08/13          2019          August           13.0
# 206432     2019/08/13          2019          August           13.0
# 206433     2019/08/13          2019          August           13.0
# 206434     2019/08/13          2019          August           13.0
#
#        occurrencedayofweek  occurrencehour              MCI
# 0               Tuesday                 22          Assault
# 1               Tuesday                 22          Assault
# 2               Tuesday                 22          Assault
# 3               Tuesday                 22          Assault
# 4               Tuesday                 21  Break and Enter
# ...                    ...             ...              ...
# 206430          Tuesday                 17       Auto Theft
# 206431          Tuesday                 14       Auto Theft
# 206432          Tuesday                 13       Auto Theft
# 206433          Tuesday                 11       Auto Theft
# 206434          Tuesday                 22       Auto Theft
#
# [206435 rows x 7 columns]

# %%
#Rename Occurence Column to merge with df2
df1 = df1.rename({'occurrencedate': 'Date'}, axis=1)
df1 = df1.rename({'occurrencehour':'hour_num'}, axis=1)          
df1.head()
# Out:
#          Date  reportedyear occurrencemonth  occurrenceday  \
# 0  2014/01/07          2014         January            7.0
# 1  2014/01/07          2014         January            7.0
# 2  2014/01/07          2014         January            7.0
# 3  2014/01/07          2014         January            7.0
# 4  2014/01/07          2014         January            7.0
#
#   occurrencedayofweek  hour_num              MCI
# 0          Tuesday           22          Assault
# 1          Tuesday           22          Assault
# 2          Tuesday           22          Assault
# 3          Tuesday           22          Assault
# 4          Tuesday           21  Break and Enter

# %%
# convert the 'Date' column to datetime format
df1['Date'] = pd.to_datetime(df1['Date'], infer_datetime_format=True)
df1
#set start and end date for years we want to keep
start_date = '01-08-2014'
end_date = '11-14-2018'
#Add them to the df2
mask = (df1['Date'] > start_date) & (df1['Date'] <= end_date)
df1 = df1.loc[mask]
df1
#convert occurenceday column to integer
df1['occurrenceday'] = df1['occurrenceday'].astype(int)
df1.dtypes
# Out:
# Date                   datetime64[ns]
# reportedyear                    int64
# occurrencemonth                object
# occurrenceday                   int64
# occurrencedayofweek            object
# hour_num                        int64
# MCI                            object
# dtype: object

# %%
#read in temperature data 
df2 = pd.read_csv(Path('/Users/kristenmaskery/Desktop/CrimeStoppers/Resources/Toronto_temp_clean.csv'))
df2=pd.DataFrame(df2)
df2
# Out:
#            Date_  Year_  Month_  Day_  Mean_temp  Total_Precip  Season Rain  \
# 0     2018-01-31  2,018       1    31       -7.0           1.0  Winter   No
# 1     2018-01-30  2,018       1    30      -11.0           0.0  Winter   No
# 2     2018-01-29  2,018       1    29       -4.0           5.0  Winter   No
# 3     2018-01-28  2,018       1    28        1.0           0.0  Winter   No
# 4     2018-01-27  2,018       1    27        5.0           2.0  Winter  Yes
# ...          ...    ...     ...   ...        ...           ...     ...  ...
# 2884  1941-12-01   1941      12     1       -1.5          41.1  Winter  Yes
# 2885  1940-12-01   1940      12     1       -3.6          82.6  Winter  Yes
# 2886  1939-12-01   1939      12     1        NaN           NaN  Winter   No
# 2887  1938-12-01   1938      12     1       -2.5          27.4  Winter  Yes
# 2888  1937-12-01   1937      12     1       -4.4          41.4  Winter  Yes
#
#      Snow
# 0     Yes
# 1      No
# 2     Yes
# 3      No
# 4      No
# ...   ...
# 2884  Yes
# 2885  Yes
# 2886   No
# 2887  Yes
# 2888  Yes
#
# [2889 rows x 9 columns]

# %%
#Rename Date_ Column to merge with df1
df2 = df2.rename({'Date_': 'Date'}, axis=1)
df2.head()
# Out:
#          Date  Year_  Month_  Day_  Mean_temp  Total_Precip  Season Rain Snow
# 0  2018-01-31  2,018       1    31       -7.0           1.0  Winter   No  Yes
# 1  2018-01-30  2,018       1    30      -11.0           0.0  Winter   No   No
# 2  2018-01-29  2,018       1    29       -4.0           5.0  Winter   No  Yes
# 3  2018-01-28  2,018       1    28        1.0           0.0  Winter   No   No
# 4  2018-01-27  2,018       1    27        5.0           2.0  Winter  Yes   No

# %%
#Convert Date column to date time 
df2['Date'] = pd.to_datetime(df2['Date']) 
df2.head()
#set start and end date for years we want to keep
start_date = '01-08-2014'
end_date = '01-01-2019'
#Add them to the df2
mask = (df2['Date'] > start_date) & (df2['Date'] <= end_date)
df2 = df2.loc[mask]
#Sort Values from 2014 to 2018
df2.sort_values(by=['Date'], inplace=True, ascending=True)
df2
# Out:
#            Date  Year_  Month_  Day_  Mean_temp  Total_Precip  Season Rain  \
# 146  2014-01-09  2,014       1     9      -11.0           0.0  Winter   No
# 145  2014-01-10  2,014       1    10       -3.0           3.0  Winter  Yes
# 144  2014-01-11  2,014       1    11        4.0           8.0  Winter  Yes
# 143  2014-01-12  2,014       1    12        1.0           0.0  Winter   No
# 142  2014-01-13  2,014       1    13        4.0           1.0  Winter  Yes
# ...         ...    ...     ...   ...        ...           ...     ...  ...
# 2422 2018-11-10  2,018      11    10        0.0           0.0    Fall   No
# 2421 2018-11-11  2,018      11    11        1.0           0.0    Fall   No
# 2420 2018-11-12  2,018      11    12        4.0           1.0    Fall  Yes
# 2419 2018-11-13  2,018      11    13       -1.0           1.0    Fall  Yes
# 2418 2018-11-14  2,018      11    14       -2.0           0.0    Fall   No
#
#      Snow
# 146    No
# 145   Yes
# 144    No
# 143    No
# 142    No
# ...   ...
# 2422   No
# 2421   No
# 2420   No
# 2419   No
# 2418   No
#
# [1771 rows x 9 columns]

# %%
#Export cleaned DataFrames & Connect to AWS 
#df1.to_csv('cleaned_crime_rate.csv', index = False)
#df2.to_csv('cleaned_temp_rate.csv', index = False)

# %%
#Import dependencies to connect the database 
from sqlalchemy import create_engine
from config import DB_HOST, DB_NAME,DB_USER,DB_PASS
import psycopg2

# %%
#store credentials in a variable 
conn = psycopg2.connect(dbname=DB_NAME, user=DB_USER,password=DB_PASS,host=DB_HOST)

# %%
#connect to database
cur = conn.cursor()

# %%
#connect to desired table "merged_df"
cur.execute("SELECT * FROM merged_df;")

# %%
#print table 
print(cur.fetchall())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import pandas.io.sql as sqlio

# %%
#Read database into a dataframe 
sql = "SELECT * FROM merged_df;"

# %%
merged_df = sqlio.read_sql_query(sql, conn)

# %%
#convert date column to datetime format
merged_df['date_'] = pd.to_datetime(merged_df['date_'], infer_datetime_format=True)

merged_df.dtypes
# Out:
# date_                  datetime64[ns]
# reportedyear                    int64
# occurrencemonth                object
# occurrenceday                   int64
# occurrencedayofweek            object
# hour_num                        int64
# mci                            object
# month_                        float64
# day_                          float64
# mean_temp                     float64
# total_precip                  float64
# season                         object
# rain                           object
# snow                           object
# dtype: object

# %%
#Clean merged df 
#merged_df.drop('Year_', axis=1, inplace=True)
merged_df.drop('day_', axis=1, inplace=True)
merged_df.drop('month_', axis=1, inplace=True)
merged_df
# Out:
#             date_  reportedyear occurrencemonth  occurrenceday  \
# 0      2014-01-09          2014         January              9
# 1      2014-01-09          2014         January              9
# 2      2014-01-09          2014         January              9
# 3      2014-01-09          2014         January              9
# 4      2014-01-09          2014         January              9
# ...           ...           ...             ...            ...
# 162091 2018-11-06          2018        November              6
# 162092 2018-11-06          2018        November              6
# 162093 2018-11-06          2018        November              6
# 162094 2018-11-06          2018        November              6
# 162095 2018-11-06          2018        November              6
#
#        occurrencedayofweek  hour_num         mci  mean_temp  total_precip  \
# 0               Thursday          22     Assault      -11.0           0.0
# 1               Thursday          17     Assault      -11.0           0.0
# 2               Thursday          17     Assault      -11.0           0.0
# 3               Thursday          21     Robbery      -11.0           0.0
# 4               Thursday          10  Theft Over      -11.0           0.0
# ...                    ...       ...         ...        ...           ...
# 162091          Tuesday            6  Auto Theft       12.0           7.0
# 162092          Tuesday           19  Auto Theft       12.0           7.0
# 162093          Tuesday           22  Auto Theft       12.0           7.0
# 162094          Tuesday           22  Auto Theft       12.0           7.0
# 162095          Tuesday           10     Assault       12.0           7.0
#
#         season rain snow
# 0       Winter   No   No
# 1       Winter   No   No
# 2       Winter   No   No
# 3       Winter   No   No
# 4       Winter   No   No
# ...        ...  ...  ...
# 162091    Fall  Yes   No
# 162092    Fall  Yes   No
# 162093    Fall  Yes   No
# 162094    Fall  Yes   No
# 162095    Fall  Yes   No
#
# [162096 rows x 12 columns]

# %%
#Create Second Instance of Label Encoder
label_encoder = LabelEncoder()
#Fit the Label Encoder 
label_encoder.fit(merged_df["mci"])
# Out:
# LabelEncoder()

# %%
#MCI Dictionary
Offences_num = {
    "Assault": 1,
    "Auto Theft": 2,
    "Break and Enter": 3,
    "Robbery": 4,
    "Theft Over":5,
}
#Add MCI Dictionary to DataFrame
merged_df["Offences_type"] = merged_df["mci"].apply(lambda x: Offences_num[x])
merged_df.head()
# Drop MCI & Offences_Type Columns 
#merged_df.drop(["MCI", "Offences_Type"], axis=1, inplace=True)
#merged_df.head()
# Out:
#        date_  reportedyear occurrencemonth  occurrenceday occurrencedayofweek  \
# 0 2014-01-09          2014         January              9          Thursday
# 1 2014-01-09          2014         January              9          Thursday
# 2 2014-01-09          2014         January              9          Thursday
# 3 2014-01-09          2014         January              9          Thursday
# 4 2014-01-09          2014         January              9          Thursday
#
#    hour_num         mci  mean_temp  total_precip  season rain snow  \
# 0        22     Assault      -11.0           0.0  Winter   No   No
# 1        17     Assault      -11.0           0.0  Winter   No   No
# 2        17     Assault      -11.0           0.0  Winter   No   No
# 3        21     Robbery      -11.0           0.0  Winter   No   No
# 4        10  Theft Over      -11.0           0.0  Winter   No   No
#
#    Offences_type
# 0              1
# 1              1
# 2              1
# 3              4
# 4              5

# %%
#Create Instance of Label Encoder
label_encoder = LabelEncoder()
#Fit the Label Encoder 
label_encoder.fit(merged_df["occurrencedayofweek"])
# List the Encoded Classes
list(label_encoder.classes_)
# Out:
# ['Friday    ',
#  'Monday    ',
#  'Saturday  ',
#  'Sunday    ',
#  'Thursday  ',
#  'Tuesday   ',
#  'Wednesday ']

# %%
#Weekday Dictionary
Week_day_num = {
    "Monday    ": 1,
    "Tuesday   ": 2,
    "Wednesday ": 3,
    "Thursday  ": 4,
    "Friday    ": 5,
    "Saturday  ": 6,
    "Sunday    ": 7,
}
#Add Months Dictionary to DataFrame
merged_df["occurrencedayofweek"] = merged_df["occurrencedayofweek"].apply(lambda x: Week_day_num[x])
merged_df.head()
#Drop columns
#merged_df.drop(["occurrencedayofweek"], axis=1, inplace=True)
#merged_df.head()
# Out:
#        date_  reportedyear occurrencemonth  occurrenceday  \
# 0 2014-01-09          2014         January              9
# 1 2014-01-09          2014         January              9
# 2 2014-01-09          2014         January              9
# 3 2014-01-09          2014         January              9
# 4 2014-01-09          2014         January              9
#
#    occurrencedayofweek  hour_num         mci  mean_temp  total_precip  season  \
# 0                    4        22     Assault      -11.0           0.0  Winter
# 1                    4        17     Assault      -11.0           0.0  Winter
# 2                    4        17     Assault      -11.0           0.0  Winter
# 3                    4        21     Robbery      -11.0           0.0  Winter
# 4                    4        10  Theft Over      -11.0           0.0  Winter
#
#   rain snow  Offences_type
# 0   No   No              1
# 1   No   No              1
# 2   No   No              1
# 3   No   No              4
# 4   No   No              5

# %%
#Create Instance of Label Encoder
label_encoder = LabelEncoder()
#Fit the Label Encoder 
label_encoder.fit(merged_df["occurrencemonth"])
# List the Encoded Classes
list(label_encoder.classes_)
# Out:
# ['April',
#  'August',
#  'December',
#  'February',
#  'January',
#  'July',
#  'June',
#  'March',
#  'May',
#  'November',
#  'October',
#  'September']

# %%
#Month Dictionary
months_num = {
    "January": 1,
    "February": 2,
    "March": 3,
    "April": 4,
    "May": 5,
    "June": 6,
    "July": 7,
    "August": 8,
    "September": 9,
    "October": 10,
    "November": 11,
    "December": 12,
}
#Add Months Dictionary to DataFrame
merged_df["Month"] = merged_df["occurrencemonth"].apply(lambda x: months_num[x])
merged_df.head()
# Out:
#        date_  reportedyear occurrencemonth  occurrenceday  \
# 0 2014-01-09          2014         January              9
# 1 2014-01-09          2014         January              9
# 2 2014-01-09          2014         January              9
# 3 2014-01-09          2014         January              9
# 4 2014-01-09          2014         January              9
#
#    occurrencedayofweek  hour_num         mci  mean_temp  total_precip  season  \
# 0                    4        22     Assault      -11.0           0.0  Winter
# 1                    4        17     Assault      -11.0           0.0  Winter
# 2                    4        17     Assault      -11.0           0.0  Winter
# 3                    4        21     Robbery      -11.0           0.0  Winter
# 4                    4        10  Theft Over      -11.0           0.0  Winter
#
#   rain snow  Offences_type  Month
# 0   No   No              1      1
# 1   No   No              1      1
# 2   No   No              1      1
# 3   No   No              4      1
# 4   No   No              5      1

# %%
#Create Instance of Label Encoder
label_encoder = LabelEncoder()
#Fit the Label Encoder 
label_encoder.fit(merged_df["season"])
# Out:
# LabelEncoder()

# %%
# List the Encoded Classes
list(label_encoder.classes_)

#Seasons Dictionary
seasons_num = {
    "Fall": 1,
    "Spring": 2,
    "Summer": 3,
    "Winter": 4,
}
#Add Months Dictionary to DataFrame
merged_df["Seasons_Num"] = merged_df["season"].apply(lambda x: seasons_num[x])
merged_df.head()
# Out:
#        date_  reportedyear occurrencemonth  occurrenceday  \
# 0 2014-01-09          2014         January              9
# 1 2014-01-09          2014         January              9
# 2 2014-01-09          2014         January              9
# 3 2014-01-09          2014         January              9
# 4 2014-01-09          2014         January              9
#
#    occurrencedayofweek  hour_num         mci  mean_temp  total_precip  season  \
# 0                    4        22     Assault      -11.0           0.0  Winter
# 1                    4        17     Assault      -11.0           0.0  Winter
# 2                    4        17     Assault      -11.0           0.0  Winter
# 3                    4        21     Robbery      -11.0           0.0  Winter
# 4                    4        10  Theft Over      -11.0           0.0  Winter
#
#   rain snow  Offences_type  Month  Seasons_Num
# 0   No   No              1      1            4
# 1   No   No              1      1            4
# 2   No   No              1      1            4
# 3   No   No              4      1            4
# 4   No   No              5      1            4

# %%
#Dummy Encoding the Rain & Snow Columns
temp_binary_encoded_df = pd.get_dummies(merged_df, columns=["rain", "snow"])
temp_binary_encoded_df.head()
# Out:
#        date_  reportedyear occurrencemonth  occurrenceday  \
# 0 2014-01-09          2014         January              9
# 1 2014-01-09          2014         January              9
# 2 2014-01-09          2014         January              9
# 3 2014-01-09          2014         January              9
# 4 2014-01-09          2014         January              9
#
#    occurrencedayofweek  hour_num         mci  mean_temp  total_precip  season  \
# 0                    4        22     Assault      -11.0           0.0  Winter
# 1                    4        17     Assault      -11.0           0.0  Winter
# 2                    4        17     Assault      -11.0           0.0  Winter
# 3                    4        21     Robbery      -11.0           0.0  Winter
# 4                    4        10  Theft Over      -11.0           0.0  Winter
#
#    Offences_type  Month  Seasons_Num  rain_No  rain_Yes  snow_No  snow_Yes
# 0              1      1            4        1         0        1         0
# 1              1      1            4        1         0        1         0
# 2              1      1            4        1         0        1         0
# 3              4      1            4        1         0        1         0
# 4              5      1            4        1         0        1         0

# %%
#Drop uneccesary columns 
temp_binary_encoded_df.drop('occurrencemonth', axis=1, inplace=True)
temp_binary_encoded_df.drop('mci', axis=1, inplace=True)
temp_binary_encoded_df.drop('season', axis=1, inplace=True)
temp_binary_encoded_df.head()
# Out:
#        date_  reportedyear  occurrenceday  occurrencedayofweek  hour_num  \
# 0 2014-01-09          2014              9                    4        22
# 1 2014-01-09          2014              9                    4        17
# 2 2014-01-09          2014              9                    4        17
# 3 2014-01-09          2014              9                    4        21
# 4 2014-01-09          2014              9                    4        10
#
#    mean_temp  total_precip  Offences_type  Month  Seasons_Num  rain_No  \
# 0      -11.0           0.0              1      1            4        1
# 1      -11.0           0.0              1      1            4        1
# 2      -11.0           0.0              1      1            4        1
# 3      -11.0           0.0              4      1            4        1
# 4      -11.0           0.0              5      1            4        1
#
#    rain_Yes  snow_No  snow_Yes
# 0         0        1         0
# 1         0        1         0
# 2         0        1         0
# 3         0        1         0
# 4         0        1         0

# %%
temp_binary_encoded_df.head()
# Out:
#        date_  reportedyear  occurrenceday  occurrencedayofweek  hour_num  \
# 0 2014-01-09          2014              9                    4        22
# 1 2014-01-09          2014              9                    4        17
# 2 2014-01-09          2014              9                    4        17
# 3 2014-01-09          2014              9                    4        21
# 4 2014-01-09          2014              9                    4        10
#
#    mean_temp  total_precip  Offences_type  Month  Seasons_Num  rain_No  \
# 0      -11.0           0.0              1      1            4        1
# 1      -11.0           0.0              1      1            4        1
# 2      -11.0           0.0              1      1            4        1
# 3      -11.0           0.0              4      1            4        1
# 4      -11.0           0.0              5      1            4        1
#
#    rain_Yes  snow_No  snow_Yes
# 0         0        1         0
# 1         0        1         0
# 2         0        1         0
# 3         0        1         0
# 4         0        1         0

# %%
# Saving the encoded dataset
temp_binary_encoded_df.to_csv('temp_binary_encoded_df.csv', index = False)

# %%
temp_binary_encoded_df.drop_duplicates
temp_binary_encoded_df.head()
# Out:
#        date_  reportedyear  occurrenceday  occurrencedayofweek  hour_num  \
# 0 2014-01-09          2014              9                    4        22
# 1 2014-01-09          2014              9                    4        17
# 2 2014-01-09          2014              9                    4        17
# 3 2014-01-09          2014              9                    4        21
# 4 2014-01-09          2014              9                    4        10
#
#    mean_temp  total_precip  Offences_type  Month  Seasons_Num  rain_No  \
# 0      -11.0           0.0              1      1            4        1
# 1      -11.0           0.0              1      1            4        1
# 2      -11.0           0.0              1      1            4        1
# 3      -11.0           0.0              4      1            4        1
# 4      -11.0           0.0              5      1            4        1
#
#    rain_Yes  snow_No  snow_Yes
# 0         0        1         0
# 1         0        1         0
# 2         0        1         0
# 3         0        1         0
# 4         0        1         0

# %%
#Create a DataFrame of the Aggregate Crime Rate 
crime_month = pd.DataFrame(temp_binary_encoded_df.Month.value_counts().reset_index().values, columns=["Month", "AggregateCrime"])
crime_month_index = crime_month.sort_index(axis = 0, ascending=True)
crime_month_index
# Out:
#     Month  AggregateCrime
# 0      10           14959
# 1       7           14697
# 2       5           14577
# 3       8           14543
# 4       6           14466
# 5       9           14361
# 6       4           13418
# 7       3           13078
# 8      11           12997
# 9       1           12475
# 10      2           11815
# 11     12           10710

# %%
#Visualize Correlation betweeen Aggregate Crime Rate and Month
plt.scatter(crime_month_index.Month, crime_month_index.AggregateCrime)
plt.xlabel('Month') 
plt.ylabel('Crime Rate')
plt.show()

# %%
#Test Accuracy of Correlation Using Pearson's Correlation Coefficient 
pearsoncorr = crime_month_index.corr(method='pearson')
pearsoncorr
# Out:
#                    Month  AggregateCrime
# Month           1.000000        0.087221
# AggregateCrime  0.087221        1.000000

# %%
#Create a DataFrame of the Aggregate Crime Rate by Day of the Week 
Week_rate = pd.DataFrame(temp_binary_encoded_df.occurrencedayofweek.value_counts().reset_index().values, columns=["Day_Of_Week", "AggregateCrime"])
Week_rate_index = Week_rate.sort_index(axis = 0, ascending=True)
Week_rate_index
# Out:
#    Day_Of_Week  AggregateCrime
# 0            5           24648
# 1            6           24370
# 2            7           23533
# 3            4           22759
# 4            3           22433
# 5            1           22364
# 6            2           21989

# %%
#Visualize Correlation betweeen Aggregate Crime Rate and Day of the Week 
plt.scatter(Week_rate_index.Day_Of_Week, Week_rate_index.AggregateCrime)
plt.xlabel('Day of Week') 
plt.ylabel('Crime Rate')
plt.show()

# %%
#Test Accuracy of Correlation Using Pearson's Correlation Coefficient 
pearsoncorr_week = Week_rate_index.corr(method='pearson')
pearsoncorr_week
# Out:
#                 Day_Of_Week  AggregateCrime
# Day_Of_Week        1.000000        0.776441
# AggregateCrime     0.776441        1.000000

# %%
#Create a DataFrame of the Aggregate Crime Rate by Hour (24hr) 
hour_rate = pd.DataFrame(temp_binary_encoded_df.hour_num.value_counts().reset_index().values, columns=["Hour", "AggregateCrime"])
hour_crime_rate_index = hour_rate.sort_index(axis = 0, ascending=True)
hour_crime_rate_index.head()
# Out:
#    Hour  AggregateCrime
# 0     0           10403
# 1    12            9092
# 2    21            8788
# 3    18            8741
# 4    20            8651

# %%
#Visualize Correlation betweeen Aggregate Crime Rate and Hour (24hr) 
plt.scatter(hour_crime_rate_index.Hour, hour_crime_rate_index.AggregateCrime)
plt.xlabel('Hour(24hr)') 
plt.ylabel('Crime Rate')
plt.show()

# %%
#Test Accuracy of Correlation Using Pearson's Correlation Coefficient 
pearsoncorr_hour = hour_crime_rate_index.corr(method='pearson')
pearsoncorr_hour
# Out:
#                     Hour  AggregateCrime
# Hour            1.000000        0.514109
# AggregateCrime  0.514109        1.000000

# %%
#Create a DataFrame of the Aggregate Crime Rate by Temperature
Temp_rate = pd.DataFrame(temp_binary_encoded_df.mean_temp.value_counts().reset_index().values, columns=["Mean_temp", "AggregateCrime"])
temp_crime_rate_index = Temp_rate.sort_index(axis = 0, ascending=True)
temp_crime_rate_index.head()
# Out:
#    Mean_temp  AggregateCrime
# 0       22.0          7197.0
# 1       17.0          6234.0
# 2       19.0          6151.0
# 3       20.0          6126.0
# 4       21.0          5994.0

# %%
#Visualize Correlation betweeen Aggregate Crime Rate and Temperature 
plt.scatter(temp_crime_rate_index.Mean_temp, temp_crime_rate_index.AggregateCrime)
plt.xlabel('Mean_temp') 
plt.ylabel('Crime Rate')
plt.show()

# %%
#Test Accuracy of Correlation Using Pearson's Correlation Coefficient 
pearsoncorr_temp = temp_crime_rate_index.corr(method='pearson')
pearsoncorr_temp
# Out:
#                 Mean_temp  AggregateCrime
# Mean_temp        1.000000        0.570894
# AggregateCrime   0.570894        1.000000

# %% [markdown]
# # Step 2: Apply Machine Learning Models

# %%
#Analyze the Correlation Between Mean Temperature and Crime Count Using a Linear Regression Model 
#Assign X and Y Variables 
X = temp_crime_rate_index.Mean_temp.values.reshape(-1, 1)
y = temp_crime_rate_index.AggregateCrime.values.reshape(-1, 1)
#Show Variable Shape
X.shape
y.shape
# Out:
# (53, 1)

# %%
#Train, Test,and Split the Data 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Create an Instance of the Linear Regression Model
model = LinearRegression()

# %%
# Fit/Train the Model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Use Predict() Method to Generate Predictions
y_pred = model.predict(X_test)
print(y_pred.shape)
print(y_test.shape)
# Out:
# (11, 1)
# (11, 1)

# %%
#Show the Actual Versus Predicted Values 
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df
# Out:
#     Actual    Predicted
# 0    597.0  4957.233357
# 1   2108.0  2366.059256
# 2   1127.0  1832.582236
# 3   2106.0  1985.004242
# 4   4698.0  3051.958283
# 5   6151.0  4195.123327
# 6   2332.0  2518.481262
# 7    897.0  1756.371233
# 8   2533.0  2442.270259
# 9   3374.0  4728.600348
# 10  5994.0  4347.545333

# %%
#Plot Predictions 
plt.scatter(X, y)
plt.plot(X_test, y_pred, color='red')
plt.ylabel('Crime Count')
plt.xlabel('Temperature')
plt.show()

# %%
#Examine our Model
print(model.coef_)
print(model.intercept_)
# Out:
# [[76.21100295]]
# [2747.11427117]

# %%
#Check the Model's Accuracy 
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1198.5842043261398
# Mean Squared Error: 2859354.8907539477
# Root Mean Squared Error: 1690.9627112251612

# %%
#Analyze the Correlation Between Month and Aggregate Crime Using a Linear Regression Model 
#Assign X and Y Variables 
X = crime_month_index.Month.values.reshape(-1, 1)
y = crime_month_index.AggregateCrime.values.reshape(-1, 1)
#Show Variable Shape
X.shape
y.shape
# Out:
# (12, 1)

# %%
#Train, Test,and Split the Data 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Create an Instance of the Linear Regression Model
model = LinearRegression()

# %%
# Fit/Train the Model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Use Predict() Method to Generate Predictions
y_pred = model.predict(X_test)
print(y_pred.shape)
print(y_test.shape)
# Out:
# (3, 1)
# (3, 1)

# %%
#Show the Actual Versus Predicted Values 
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df
# Out:
#    Actual     Predicted
# 0   13418  13427.283217
# 1   10710  13685.576923
# 2   14466  13491.856643

# %%
#Plot Predictions 
plt.scatter(X, y)
plt.plot(X_test, y_pred, color='red')
plt.ylabel('Crime Count')
plt.xlabel('Month')
plt.show()

# %%
#Examine our Model
print(model.coef_)
print(model.intercept_)
# Out:
# [[32.28671329]]
# [13298.13636364]

# %%
#Check the Model's Accuracy 
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1319.6678321678326
# Mean Squared Error: 3267699.8275180547
# Root Mean Squared Error: 1807.6780209755427

# %%
#Analyze the Correlation Between Day of the Week and Crime Count Using a Linear Regression Model 
#Assign X and Y Variables 
X = Week_rate_index.Day_Of_Week.values.reshape(-1, 1)
y = Week_rate_index.AggregateCrime.values.reshape(-1, 1)
#Show Variable Shape
X.shape
y.shape
# Out:
# (7, 1)

# %%
#Train, Test,and Split the Data 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Create an Instance of the Linear Regression Model
model = LinearRegression()

# %%
# Fit/Train the Model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Use Predict() Method to Generate Predictions
y_pred = model.predict(X_test)
print(y_pred.shape)
print(y_test.shape)
# Out:
# (2, 1)
# (2, 1)

# %%
#Show the Actual Versus Predicted Values 
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df
# Out:
#    Actual     Predicted
# 0   21989  22407.714286
# 1   23533  24279.857143

# %%
#Plot Predictions 
plt.scatter(X, y)
plt.plot(X_test, y_pred, color='red')
plt.ylabel('Crime Count')
plt.xlabel('Day of Week')
plt.show()

# %%
#Examine our Model
print(model.coef_)
print(model.intercept_)
# Out:
# [[374.42857143]]
# [21658.85714286]

# %%
#Check the Model's Accuracy 
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 582.785714285712
# Mean Squared Error: 366558.6224489771
# Root Mean Squared Error: 605.4408496698725

# %%
#Analyze the Correlation Between Hour of the Day and Crime Count Using a Linear Regression Model 
#Assign X and Y Variables 
X = hour_crime_rate_index.Hour.values.reshape(-1, 1)
y = hour_crime_rate_index.AggregateCrime.values.reshape(-1, 1)
#Show Variable Shape
X.shape
y.shape
# Out:
# (24, 1)

# %%
#Train, Test,and Split the Data 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Create an Instance of the Linear Regression Model
model = LinearRegression()

# %%
# Fit/Train the Model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Use Predict() Method to Generate Predictions
y_pred = model.predict(X_test)
print(y_pred.shape)
print(y_test.shape)
# Out:
# (5, 1)
# (5, 1)

# %%
#Show the Actual Versus Predicted Values 
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df
# Out:
#    Actual    Predicted
# 0    7047  5274.593913
# 1    7766  7454.771304
# 2    2856  5741.774783
# 3    6424  6987.590435
# 4    3777  5586.047826

# %%
#Plot Predictions 
plt.scatter(X, y)
plt.plot(X_test, y_pred, color='red')
plt.ylabel('Crime Count')
plt.xlabel('Hour (24hr)')
plt.show()

# %%
#Examine our Model
print(model.coef_)
print(model.intercept_)
# Out:
# [[155.72695652]]
# [4963.14]

# %%
#Check the Model's Accuracy 
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1468.4095652173914
# Mean Squared Error: 3031254.189853309
# Root Mean Squared Error: 1741.0497379033459

# %% [markdown]
# # Machine Learning Model: Facebook Prophet Model

# %%
#Import Dependencies 
from fbprophet import Prophet

# %%
#Create a date and crime dataframe 
prophet_df = pd.DataFrame(temp_binary_encoded_df.date_.value_counts().reset_index().values, columns=["ds", "y"])
prophet_df_index = prophet_df.sort_index(axis = 0, ascending=True)
prophet_df_index.head()
# Out:
#           ds    y
# 0 2015-01-01  220
# 1 2018-01-01  216
# 2 2017-01-01  189
# 3 2016-01-01  174
# 4 2018-06-01  172

# %%
#Fit the Prophet model to the dataframe 
m = Prophet()
m.fit(prophet_df_index)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
#Create Future dataframe 
future = m.make_future_dataframe(periods=1800)
future.tail()
# Out:
#              ds
# 3566 2023-10-15
# 3567 2023-10-16
# 3568 2023-10-17
# 3569 2023-10-18
# 3570 2023-10-19

# %%
#Create forecasted dataframe 
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds        yhat  yhat_lower  yhat_upper
# 3566 2023-10-15  121.163087  102.071184  140.550179
# 3567 2023-10-16  117.035985   96.469763  136.380943
# 3568 2023-10-17  116.087142   97.495447  135.796754
# 3569 2023-10-18  118.407171   98.463464  139.375755
# 3570 2023-10-19  120.388839  101.889430  139.742629

# %%
# Plot the forecasted dataframe 
fig1 = m.plot(forecast)

# %%
#Plot components of the forecasted datat 
fig2 = m.plot_components(forecast)

# %%
#Import plotly to build interactive model 
from fbprophet.plot import plot_plotly, plot_components_plotly

# %%
#Make an interactive plot for forecasted data 
plot_plotly(m, forecast)
# Out:
# <div>                            <div id="240fc893-8d26-48a8-9c7b-948c9ba54fbb" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("240fc893-8d26-48a8-9c7b-948c9ba54fbb")) {                    Plotly.newPlot(                        "240fc893-8d26-48a8-9c7b-948c9ba54fbb",                        [{"marker": {"color": "black", "size": 4}, "mode": "markers", "name": "Actual", "type": "scatter", "x": ["2014-01-09T00:00:00", "2014-01-10T00:00:00", "2014-01-11T00:00:00", "2014-01-12T00:00:00", "2014-01-13T00:00:00", "2014-01-14T00:00:00", "2014-01-15T00:00:00", "2014-01-16T00:00:00", "2014-01-17T00:00:00", "2014-01-18T00:00:00", "2014-01-19T00:00:00", "2014-01-20T00:00:00", "2014-01-21T00:00:00", "2014-01-22T00:00:00", "2014-01-23T00:00:00", "2014-01-24T00:00:00", "2014-01-25T00:00:00", "2014-01-26T00:00:00", "2014-01-27T00:00:00", "2014-01-28T00:00:00", "2014-01-29T00:00:00", "2014-01-30T00:00:00", "2014-01-31T00:00:00", "2014-02-01T00:00:00", "2014-02-02T00:00:00", "2014-02-03T00:00:00", "2014-02-04T00:00:00", "2014-02-05T00:00:00", "2014-02-06T00:00:00", "2014-02-07T00:00:00", "2014-02-08T00:00:00", "2014-02-09T00:00:00", "2014-02-10T00:00:00", "2014-02-11T00:00:00", "2014-02-12T00:00:00", "2014-02-13T00:00:00", "2014-02-14T00:00:00", "2014-02-15T00:00:00", "2014-02-16T00:00:00", "2014-02-17T00:00:00", "2014-02-18T00:00:00", "2014-02-19T00:00:00", "2014-02-20T00:00:00", "2014-02-21T00:00:00", "2014-02-22T00:00:00", "2014-02-23T00:00:00", "2014-02-24T00:00:00", "2014-02-25T00:00:00", "2014-02-26T00:00:00", "2014-02-27T00:00:00", "2014-02-28T00:00:00", "2014-03-01T00:00:00", "2014-03-02T00:00:00", "2014-03-03T00:00:00", "2014-03-04T00:00:00", "2014-03-05T00:00:00", "2014-03-06T00:00:00", "2014-03-07T00:00:00", "2014-03-08T00:00:00", "2014-03-09T00:00:00", "2014-03-10T00:00:00", "2014-03-11T00:00:00", "2014-03-12T00:00:00", "2014-03-13T00:00:00", "2014-03-14T00:00:00", "2014-03-15T00:00:00", "2014-03-16T00:00:00", "2014-03-17T00:00:00", "2014-03-18T00:00:00", "2014-03-19T00:00:00", "2014-03-20T00:00:00", "2014-03-21T00:00:00", "2014-03-22T00:00:00", "2014-03-23T00:00:00", "2014-03-24T00:00:00", "2014-03-25T00:00:00", "2014-03-26T00:00:00", "2014-03-27T00:00:00", "2014-03-28T00:00:00", "2014-03-29T00:00:00", "2014-03-30T00:00:00", "2014-03-31T00:00:00", "2014-04-01T00:00:00", "2014-04-02T00:00:00", "2014-04-03T00:00:00", "2014-04-04T00:00:00", "2014-04-05T00:00:00", "2014-04-06T00:00:00", "2014-04-07T00:00:00", "2014-04-08T00:00:00", "2014-04-09T00:00:00", "2014-04-10T00:00:00", "2014-04-11T00:00:00", "2014-04-12T00:00:00", "2014-04-13T00:00:00", "2014-04-14T00:00:00", "2014-04-15T00:00:00", "2014-04-16T00:00:00", "2014-04-17T00:00:00", "2014-04-18T00:00:00", "2014-04-19T00:00:00", "2014-04-20T00:00:00", "2014-04-21T00:00:00", "2014-04-22T00:00:00", "2014-04-23T00:00:00", "2014-04-24T00:00:00", "2014-04-25T00:00:00", "2014-04-26T00:00:00", "2014-04-27T00:00:00", "2014-04-28T00:00:00", "2014-04-29T00:00:00", "2014-04-30T00:00:00", "2014-05-01T00:00:00", "2014-05-02T00:00:00", "2014-05-03T00:00:00", "2014-05-04T00:00:00", "2014-05-05T00:00:00", "2014-05-06T00:00:00", "2014-05-07T00:00:00", "2014-05-08T00:00:00", "2014-05-09T00:00:00", "2014-05-10T00:00:00", "2014-05-11T00:00:00", "2014-05-12T00:00:00", "2014-05-13T00:00:00", "2014-05-14T00:00:00", "2014-05-15T00:00:00", "2014-05-16T00:00:00", "2014-05-17T00:00:00", "2014-05-18T00:00:00", "2014-05-19T00:00:00", "2014-05-20T00:00:00", "2014-05-21T00:00:00", "2014-05-22T00:00:00", "2014-05-23T00:00:00", "2014-05-24T00:00:00", "2014-05-25T00:00:00", "2014-05-26T00:00:00", "2014-05-27T00:00:00", "2014-05-28T00:00:00", "2014-05-29T00:00:00", "2014-05-30T00:00:00", "2014-05-31T00:00:00", "2014-06-01T00:00:00", "2014-06-02T00:00:00", "2014-06-03T00:00:00", "2014- ...

# %%
# changing trend points
from fbprophet.plot import add_changepoints_to_plot
fig=m.plot(forecast)
a=add_changepoints_to_plot(fig.gca(),m,forecast)

# %%
# Import dependencies for cross validation 
from fbprophet.diagnostics import cross_validation
prophet_df_index.shape
# Out:
# (1771, 2)

# %%
#Perform cross validation 
cv = cross_validation(m, initial = "15 days", period = "360 days", horizon = "1600 days")
cv.head()
# Out:
# INFO:fbprophet:Making 1 forecasts with cutoffs between 2014-06-28 00:00:00 and 2014-06-28 00:00:00
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
#           ds        yhat  yhat_lower  yhat_upper    y     cutoff
# 0 2014-06-29   91.606797   75.935428  106.718993   98 2014-06-28
# 1 2014-06-30   89.892283   75.790253  104.614939   92 2014-06-28
# 2 2014-07-01   95.394128   81.048281  109.898079  132 2014-06-28
# 3 2014-07-02   92.655301   78.733143  108.331422   81 2014-06-28
# 4 2014-07-03  100.617125   84.847581  115.185297   89 2014-06-28

# %%
#Import dependency for checking model accuracy 
from fbprophet.diagnostics import performance_metrics

# %%
#Check model's accuracy 
df_pm = performance_metrics(cv)
df_pm
# Out:
#        horizon            mse        rmse         mae      mape     mdape  \
# 0     160 days    1512.718052   38.893676   34.792382  0.415776  0.389082
# 1     161 days    1526.791445   39.074179   35.051682  0.418694  0.391289
# 2     162 days    1537.520848   39.211234   35.297801  0.421497  0.395527
# 3     163 days    1541.460468   39.261437   35.346441  0.423067  0.400810
# 4     164 days    1568.281366   39.601532   35.689453  0.428283  0.404078
# ...        ...            ...         ...         ...       ...       ...
# 1436 1596 days  118043.859191  343.575114  342.822852  3.499461  3.479786
# 1437 1597 days  118208.319863  343.814368  343.066811  3.497670  3.479786
# 1438 1598 days  118393.458059  344.083504  343.329931  3.497624  3.479786
# 1439 1599 days  118873.019279  344.779668  344.019513  3.517852  3.481120
# 1440 1600 days  119158.307776  345.193146  344.434168  3.525377  3.481940
#
#       coverage
# 0      0.14375
# 1      0.13750
# 2      0.13125
# 3      0.13125
# 4      0.12500
# ...        ...
# 1436   0.00000
# 1437   0.00000
# 1438   0.00000
# 1439   0.00000
# 1440   0.00000
#
# [1441 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6c7aedb8f4ed> in <module>
#       1 with open('model.pckl', 'rb') as fout:
# ----> 2     pickle.dump(m, fout)
#
# NameError: name 'm' is not defined
